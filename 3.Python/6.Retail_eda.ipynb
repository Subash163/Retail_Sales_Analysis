# %%
# Retail Sales Analysis

## Objective
"""

The objective of this project is to analyze retail sales performance using a normalized MySQL database.

Project Workflow

- Excel Data Cleaning
- MySQL Database Design
- SQL Business Analysis
- Python Exploratory Data Analysis
- Power BI Dashboard

Dataset Source:
Sample Superstore Dataset
"""

# %%
# Import Custom Modules

from database import load_data
from preprocessing import (
    preprocess_data,
    check_shape,
    check_data_types,
    check_missing_values,
    check_duplicate_rows,
    check_unique_values,
    statistical_summary,
    shipping_validation
)

from eda import *
# Out:
# Step 1: database.py started

# %%
# Load Dataset

# %%
df = load_data()

# %%
df.head()

# %%
# Data Validation

# %%
check_shape(df)

# %%
check_data_types(df)

# %%
check_duplicate_rows(df)

# %%
check_unique_values(df)

# %%
statistical_summary(df)

# %%
shipping_validation(df)

# %%
# Feature Engineering

# %%
df = preprocess_data(df)

# %%
df.head()

# %%
overall_kpis(df)

# %%
sales_summary(df)

# %%
sales_summary(df)

# %%
customer_summary(df)

# %%
product_summary(df)

# %%
region_summary(df)

# %%
state_summary(df)

# %%
city_summary(df)

# %%
segment_summary(df)

# %%
shipmode_summary(df)

# %%
monthly_sales(df)

# %%
top_customers(df)

# %%
top_products(df)

# %%
loss_products(df)

# %%
high_discount_products(df)

# %%
correlation_matrix(df)

# %%
from visualization import sales_by_category

sales_by_category(df)

# %%
from visualization import *

profit_by_category(df)
