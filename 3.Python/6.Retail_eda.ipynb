# %%
# Retail Sales Analysis

## Objective

The objective of this project is to analyze retail sales performance using a normalized MySQL database.

Project Workflow

- Excel Data Cleaning
- MySQL Database Design
- SQL Business Analysis
- Python Exploratory Data Analysis
- Power BI Dashboard

Dataset Source:
Sample Superstore Dataset

# %%
# Import Custom Modules

from database import load_data
from preprocessing import (
    preprocess_data,
    check_shape,
    check_data_types,
    check_missing_values,
    check_duplicate_rows,
    check_unique_values,
    statistical_summary,
    shipping_validation
)

from eda import *
# Out:
# Step 1: database.py started

# %%
# Load Dataset

# %%
df = load_data()
# Out:
# Step 4: Loading Tables
# Step 2: Creating SQLAlchemy Engine
# Customers Loaded
# Products Loaded
# Orders Loaded
# Sales Loaded
# ✅ Tables Loaded Successfully
#
# ✅ Tables Merged Successfully

# %%
df.head()

# %%
# Data Validation

# %%
check_shape(df)
# Out:
# (9994, 21)

# %%
check_data_types(df)

# %%
check_duplicate_rows(df)
# Out:
# np.int64(0)

# %%
check_unique_values(df)

# %%
statistical_summary(df)

# %%
shipping_validation(df)

# %%
# Feature Engineering

# %%
df = preprocess_data(df)

# %%
df.head()
# Out:
#    Sales_ID        Order_ID       Product_ID   Sales  Quantity  Discount  \
# 0         1  CA-2016-152156  FUR-BO-10001798  261.96         2      0.00
# 1         2  CA-2016-152156  FUR-CH-10000454  731.94         3      0.00
# 2         3  CA-2016-138688  OFF-LA-10000240   14.62         2      0.00
# 3         4  US-2015-108966  FUR-TA-10000577  957.58         5      0.45
# 4         5  US-2015-108966  OFF-ST-10000760   22.37         2      0.20
#
#      Profit Customer_ID Order_Date  Ship_Date  ...  \
# 0   41.9136    CG-12520 2016-11-08 2016-11-11  ...
# 1  219.5820    CG-12520 2016-11-08 2016-11-11  ...
# 2    6.8714    DV-13045 2016-06-12 2016-06-16  ...
# 3 -383.0310    SO-20335 2015-10-11 2015-10-18  ...
# 4    2.5164    SO-20335 2015-10-11 2015-10-18  ...
#
#                                         Product_Name Order_Year  \
# 0                  Bush Somerset Collection Bookcase       2016
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...       2016
# 2  Self-Adhesive Address Labels for Typewriters b...       2016
# 3      Bretford CR4500 Series Slim Rectangular Table       2015
# 4                     Eldon Fold 'N Roll Cart System       2015
#
#   Order_Month_No Order_Month Quarter Day_Name Week_Number Processing_Days  \
# 0             11    November       4  Tuesday          45               3
# 1             11    November       4  Tuesday          45               3
# 2              6        June       2   Sunday          23               4
# 3             10     October       4   Sunday          41               7
# 4             10     October       4   Sunday          41               7
#
#   Profit_Margin Average_Selling_Price
# 0     16.000000               130.980
# 1     30.000000               243.980
# 2     47.000000                 7.310
# 3    -39.999896               191.516
# 4     11.248994                11.185
#
# [5 rows x 30 columns]

# %%
overall_kpis(df)
# Out:
# {'Total Sales': np.float64(2297201.07),
#  'Total Profit': np.float64(286397.02),
#  'Total Orders': 5009,
#  'Total Customers': 793,
#  'Total Products': 1862,
#  'Total Quantity': np.int64(37873),
#  'Average Sales': np.float64(229.86),
#  'Average Profit': np.float64(28.66),
#  'Average Discount': np.float64(0.16)}

# %%
sales_summary(df)

# %%
sales_summary(df)

# %%
customer_summary(df)

# %%
product_summary(df)

# %%
region_summary(df)

# %%
state_summary(df)

# %%
city_summary(df)

# %%
segment_summary(df)

# %%
shipmode_summary(df)

# %%
monthly_sales(df)

# %%
top_customers(df)

# %%
top_products(df)

# %%
loss_products(df)

# %%
high_discount_products(df)

# %%
correlation_matrix(df)

# %%
from visualization import sales_by_category

sales_by_category(df)

# %%
from visualization import *

profit_by_category(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from visualization import *
# ----> 3 profit_by_category(df)
#
# NameError: name 'profit_by_category' is not defined
